# %%
from onnx_coreml import convert

# Load the ONNX model as a CoreML model
mlmodel = convert(model='../models/colorizer.onnx', minimum_ios_deployment_target='13', add_custom_layers=True)
# Step 2 - ONNX to CoreML model
# rename inputs/outputs
#import coremltools
#spec = mlmodel.get_spec()
#coremltools.utils.rename_feature(spec, current_name='input.1', new_name='input_tensor')
#coremltools.utils.rename_feature(spec, current_name='12', new_name='network_output')
#mlmodel = coremltools.models.MLModel(spec)

# Save converted CoreML model
#mlmodel.save('small_model.mlmodel')
# Save the CoreML model
#model.save('colorizer.mlmodel')
mlmodel
# Out:
# 1/460: Converting Node Type Conv
# 2/460: Converting Node Type BatchNormalization
# 3/460: Converting Node Type Relu
# 4/460: Converting Node Type MaxPool
# 5/460: Converting Node Type Conv
# 6/460: Converting Node Type BatchNormalization
# 7/460: Converting Node Type Relu
# 8/460: Converting Node Type Conv
# 9/460: Converting Node Type BatchNormalization
# 10/460: Converting Node Type Relu
# 11/460: Converting Node Type Conv
# 12/460: Converting Node Type BatchNormalization
# 13/460: Converting Node Type Conv
# 14/460: Converting Node Type BatchNormalization
# 15/460: Converting Node Type Add
# 16/460: Converting Node Type Relu
# 17/460: Converting Node Type Conv
# 18/460: Converting Node Type BatchNormalization
# 19/460: Converting Node Type Relu
# 20/460: Converting Node Type Conv
# 21/460: Converting Node Type BatchNormalization
# 22/460: Converting Node Type Relu
# 23/460: Converting Node Type Conv
# 24/460: Converting Node Type BatchNormalization
# 25/460: Converting Node Type Add
# 26/460: Converting Node Type Relu
# 27/460: Converting Node Type Conv
# 28/460: Converting Node Type BatchNormalization
# 29/460: Converting Node Type Relu
# 30/460: Converting Node Type Conv
# 31/460: Converting Node Type BatchNormalization
# 32/460: Converting Node Type Relu
# 33/460: Converting Node Type Conv
# 34/460: Converting Node Type BatchNormalization
# 35/460: Converting Node Type Add
# 36/460: Converting Node Type Relu
# 37/460: Converting Node Type Conv
# 38/460: Converting Node Type BatchNormalization
# 39/460: Converting Node Type Relu
# 40/460: Converting Node Type Conv
# 41/460: Converting Node Type BatchNormalization
# 42/460: Converting Node Type Relu
# 43/460: Converting Node Type Conv
# 44/460: Converting Node Type BatchNormalization
# 45/460: Converting Node Type Conv
# 46/460: Converting Node Type BatchNormalization
# 47/460: Converting Node Type Add
# 48/460: Converting Node Type Relu
# 49/460: Converting Node Type Conv
# 50/460: Converting Node Type BatchNormalization
# 51/460: Converting Node Type Relu
# 52/460: Converting Node Type Conv
# 53/460: Converting Node Type BatchNormalization
# 54/460: Converting Node Type Relu
# 55/460: Converting Node Type Conv
# 56/460: Converting Node Type BatchNormalization
# 57/460: Converting Node Type Add
# 58/460: Converting Node Type Relu
# 59/460: Converting Node Type Conv
# 60/460: Converting Node Type BatchNormalization
# 61/460: Converting Node Type Relu
# 62/460: Converting Node Type Conv
# 63/460: Converting Node Type BatchNormalization
# 64/460: Converting Node Type Relu
# 65/460: Converting Node Type Conv
# 66/460: Converting Node Type BatchNormalization
# 67/460: Converting Node Type Add
# 68/460: Converting Node Type Relu
# 69/460: Converting Node Type Conv
# 70/460: Converting Node Type BatchNormalization
# 71/460: Converting Node Type Relu
# 72/460: Converting Node Type Conv
# 73/460: Converting Node Type BatchNormalization
# 74/460: Converting Node Type Relu
# 75/460: Converting Node Type Conv
# 76/460: Converting Node Type BatchNormalization
# 77/460: Converting Node Type Add
# 78/460: Converting Node Type Relu
# 79/460: Converting Node Type Conv
# 80/460: Converting Node Type BatchNormalization
# 81/460: Converting Node Type Relu
# 82/460: Converting Node Type Conv
# 83/460: Converting Node Type BatchNormalization
# 84/460: Converting Node Type Relu
# 85/460: Converting Node Type Conv
# 86/460: Converting Node Type BatchNormalization
# 87/460: Converting Node Type Conv
# 88/460: Converting Node Type BatchNormalization
# 89/460: Converting Node Type Add
# 90/460: Converting Node Type Relu
# 91/460: Converting Node Type Conv
# 92/460: Converting Node Type BatchNormalization
# 93/460: Converting Node Type Relu
# 94/460: Converting Node Type Conv
# 95/460: Converting Node Type BatchNormalization
# 96/460: Converting Node Type Relu
# 97/460: Converting Node Type Conv
# 98/460: Converting Node Type BatchNormalization
# 99/460: Converting Node Type Add
# 100/460: Converting Node Type Relu
# 101/460: Converting Node Type Conv
# 102/460: Converting Node Type BatchNormalization
# 103/460: Converting Node Type Relu
# 104/460: Converting Node Type Conv
# 105/460: Converting Node Type BatchNormalization
# 106/460: Converting Node Type Relu
# 107/460: Converting Node Type Conv
# 108/460: Converting Node Type BatchNormalization
# 109/460: Converting Node Type Add
# 110/460: Converting Node Type Relu
# 111/460: Converting Node Type Conv
# 112/460: Converting Node Type BatchNormalization
# 113/460: Converting Node Type Relu
# 114/460: Converting Node Type Conv
# 115/460: Converting Node Type BatchNormalization
# 116/460: Converting Node Type Relu
# 117/460: Converting Node Type Conv
# 118/460: Converting Node Type BatchNormalization
# 119/460: Converting Node Type Add
# 120/460: Converting Node Type Relu
# 121/460: Converting Node Type Conv
# 122/460: Converting Node Type BatchNormalization
# 123/460: Converting Node Type Relu
# 124/460: Converting Node Type Conv
# 125/460: Converting Node Type BatchNormalization
# 126/460: Converting Node Type Relu
# 127/460: Converting Node Type Conv
# 128/460: Converting Node Type BatchNormalization
# 129/460: Converting Node Type Add
# 130/460: Converting Node Type Relu
# 131/460: Converting Node Type Conv
# 132/460: Converting Node Type BatchNormalization
# 133/460: Converting Node Type Relu
# 134/460: Converting Node Type Conv
# 135/460: Converting Node Type BatchNormalization
# 136/460: Converting Node Type Relu
# 137/460: Converting Node Type Conv
# 138/460: Converting Node Type BatchNormalization
# 139/460: Converting Node Type Add
# 140/460: Converting Node Type Relu
# 141/460: Converting Node Type Conv
# 142/460: Converting Node Type BatchNormalization
# 143/460: Converting Node Type Relu
# 144/460: Converting Node Type Conv
# 145/460: Converting Node Type BatchNormalization
# 146/460: Converting Node Type Relu
# 147/460: Converting Node Type Conv
# 148/460: Converting Node Type BatchNormalization
# 149/460: Converting Node Type Add
# 150/460: Converting Node Type Relu
# 151/460: Converting Node Type Conv
# 152/460: Converting Node Type BatchNormalization
# 153/460: Converting Node Type Relu
# 154/460: Converting Node Type Conv
# 155/460: Converting Node Type BatchNormalization
# 156/460: Converting Node Type Relu
# 157/460: Converting Node Type Conv
# 158/460: Converting Node Type BatchNormalization
# 159/460: Converting Node Type Add
# 160/460: Converting Node Type Relu
# 161/460: Converting Node Type Conv
# 162/460: Converting Node Type BatchNormalization
# 163/460: Converting Node Type Relu
# 164/460: Converting Node Type Conv
# 165/460: Converting Node Type BatchNormalization
# 166/460: Converting Node Type Relu
# 167/460: Converting Node Type Conv
# 168/460: Converting Node Type BatchNormalization
# 169/460: Converting Node Type Add
# 170/460: Converting Node Type Relu
# 171/460: Converting Node Type Conv
# 172/460: Converting Node Type BatchNormalization
# 173/460: Converting Node Type Relu
# 174/460: Converting Node Type Conv
# 175/460: Converting Node Type BatchNormalization
# 176/460: Converting Node Type Relu
# 177/460: Converting Node Type Conv
# 178/460: Converting Node Type BatchNormalization
# 179/460: Converting Node Type Add
# 180/460: Converting Node Type Relu
# 181/460: Converting Node Type Conv
# 182/460: Converting Node Type BatchNormalization
# 183/460: Converting Node Type Relu
# 184/460: Converting Node Type Conv
# 185/460: Converting Node Type BatchNormalization
# 186/460: Converting Node Type Relu
# 187/460: Converting Node Type Conv
# 188/460: Converting Node Type BatchNormalization
# 189/460: Converting Node Type Add
# 190/460: Converting Node Type Relu
# 191/460: Converting Node Type Conv
# 192/460: Converting Node Type BatchNormalization
# 193/460: Converting Node Type Relu
# 194/460: Converting Node Type Conv
# 195/460: Converting Node Type BatchNormalization
# 196/460: Converting Node Type Relu
# 197/460: Converting Node Type Conv
# 198/460: Converting Node Type BatchNormalization
# 199/460: Converting Node Type Add
# 200/460: Converting Node Type Relu
# 201/460: Converting Node Type Conv
# 202/460: Converting Node Type BatchNormalization
# 203/460: Converting Node Type Relu
# 204/460: Converting Node Type Conv
# 205/460: Converting Node Type BatchNormalization
# 206/460: Converting Node Type Relu
# 207/460: Converting Node Type Conv
# 208/460: Converting Node Type BatchNormalization
# 209/460: Converting Node Type Add
# 210/460: Converting Node Type Relu
# 211/460: Converting Node Type Conv
# 212/460: Converting Node Type BatchNormalization
# 213/460: Converting Node Type Relu
# 214/460: Converting Node Type Conv
# 215/460: Converting Node Type BatchNormalization
# 216/460: Converting Node Type Relu
# 217/460: Converting Node Type Conv
# 218/460: Converting Node Type BatchNormalization
# 219/460: Converting Node Type Add
# 220/460: Converting Node Type Relu
# 221/460: Converting Node Type Conv
# 222/460: Converting Node Type BatchNormalization
# 223/460: Converting Node Type Relu
# 224/460: Converting Node Type Conv
# 225/460: Converting Node Type BatchNormalization
# 226/460: Converting Node Type Relu
# 227/460: Converting Node Type Conv
# 228/460: Converting Node Type BatchNormalization
# 229/460: Converting Node Type Add
# 230/460: Converting Node Type Relu
# 231/460: Converting Node Type Conv
# 232/460: Converting Node Type BatchNormalization
# 233/460: Converting Node Type Relu
# 234/460: Converting Node Type Conv
# 235/460: Converting Node Type BatchNormalization
# 236/460: Converting Node Type Relu
# 237/460: Converting Node Type Conv
# 238/460: Converting Node Type BatchNormalization
# 239/460: Converting Node Type Add
# 240/460: Converting Node Type Relu
# 241/460: Converting Node Type Conv
# 242/460: Converting Node Type BatchNormalization
# 243/460: Converting Node Type Relu
# 244/460: Converting Node Type Conv
# 245/460: Converting Node Type BatchNormalization
# 246/460: Converting Node Type Relu
# 247/460: Converting Node Type Conv
# 248/460: Converting Node Type BatchNormalization
# 249/460: Converting Node Type Add
# 250/460: Converting Node Type Relu
# 251/460: Converting Node Type Conv
# 252/460: Converting Node Type BatchNormalization
# 253/460: Converting Node Type Relu
# 254/460: Converting Node Type Conv
# 255/460: Converting Node Type BatchNormalization
# 256/460: Converting Node Type Relu
# 257/460: Converting Node Type Conv
# 258/460: Converting Node Type BatchNormalization
# 259/460: Converting Node Type Add
# 260/460: Converting Node Type Relu
# 261/460: Converting Node Type Conv
# 262/460: Converting Node Type BatchNormalization
# 263/460: Converting Node Type Relu
# 264/460: Converting Node Type Conv
# 265/460: Converting Node Type BatchNormalization
# 266/460: Converting Node Type Relu
# 267/460: Converting Node Type Conv
# 268/460: Converting Node Type BatchNormalization
# 269/460: Converting Node Type Add
# 270/460: Converting Node Type Relu
# 271/460: Converting Node Type Conv
# 272/460: Converting Node Type BatchNormalization
# 273/460: Converting Node Type Relu
# 274/460: Converting Node Type Conv
# 275/460: Converting Node Type BatchNormalization
# 276/460: Converting Node Type Relu
# 277/460: Converting Node Type Conv
# 278/460: Converting Node Type BatchNormalization
# 279/460: Converting Node Type Add
# 280/460: Converting Node Type Relu
# 281/460: Converting Node Type Conv
# 282/460: Converting Node Type BatchNormalization
# 283/460: Converting Node Type Relu
# 284/460: Converting Node Type Conv
# 285/460: Converting Node Type BatchNormalization
# 286/460: Converting Node Type Relu
# 287/460: Converting Node Type Conv
# 288/460: Converting Node Type BatchNormalization
# 289/460: Converting Node Type Add
# 290/460: Converting Node Type Relu
# 291/460: Converting Node Type Conv
# 292/460: Converting Node Type BatchNormalization
# 293/460: Converting Node Type Relu
# 294/460: Converting Node Type Conv
# 295/460: Converting Node Type BatchNormalization
# 296/460: Converting Node Type Relu
# 297/460: Converting Node Type Conv
# 298/460: Converting Node Type BatchNormalization
# 299/460: Converting Node Type Add
# 300/460: Converting Node Type Relu
# 301/460: Converting Node Type Conv
# 302/460: Converting Node Type BatchNormalization
# 303/460: Converting Node Type Relu
# 304/460: Converting Node Type Conv
# 305/460: Converting Node Type BatchNormalization
# 306/460: Converting Node Type Relu
# 307/460: Converting Node Type Conv
# 308/460: Converting Node Type BatchNormalization
# 309/460: Converting Node Type Add
# 310/460: Converting Node Type Relu
# 311/460: Converting Node Type Conv
# 312/460: Converting Node Type BatchNormalization
# 313/460: Converting Node Type Relu
# 314/460: Converting Node Type Conv
# 315/460: Converting Node Type BatchNormalization
# 316/460: Converting Node Type Relu
# 317/460: Converting Node Type Conv
# 318/460: Converting Node Type BatchNormalization
# 319/460: Converting Node Type Conv
# 320/460: Converting Node Type BatchNormalization
# 321/460: Converting Node Type Add
# 322/460: Converting Node Type Relu
# 323/460: Converting Node Type Conv
# 324/460: Converting Node Type BatchNormalization
# 325/460: Converting Node Type Relu
# 326/460: Converting Node Type Conv
# 327/460: Converting Node Type BatchNormalization
# 328/460: Converting Node Type Relu
# 329/460: Converting Node Type Conv
# 330/460: Converting Node Type BatchNormalization
# 331/460: Converting Node Type Add
# 332/460: Converting Node Type Relu
# 333/460: Converting Node Type Conv
# 334/460: Converting Node Type BatchNormalization
# 335/460: Converting Node Type Relu
# 336/460: Converting Node Type Conv
# 337/460: Converting Node Type BatchNormalization
# 338/460: Converting Node Type Relu
# 339/460: Converting Node Type Conv
# 340/460: Converting Node Type BatchNormalization
# 341/460: Converting Node Type Add
# 342/460: Converting Node Type Relu
# 343/460: Converting Node Type BatchNormalization
# 344/460: Converting Node Type Relu
# 345/460: Converting Node Type Conv
# 346/460: Converting Node Type Relu
# 347/460: Converting Node Type BatchNormalization
# 348/460: Converting Node Type Conv
# 349/460: Converting Node Type Relu
# 350/460: Converting Node Type BatchNormalization
# 351/460: Converting Node Type Conv
# 352/460: Converting Node Type BatchNormalization
# 353/460: Converting Node Type Relu
# 354/460: Converting Node Type Reshape
# 355/460: Converting Node Type Transpose
# 356/460: Converting Node Type Reshape
# 357/460: Converting Node Type Pad
# 358/460: Converting Node Type Pad
# 359/460: Converting Node Type AveragePool
# 360/460: Converting Node Type BatchNormalization
# 361/460: Converting Node Type Concat
# 362/460: Converting Node Type Relu
# 363/460: Converting Node Type Conv
# 364/460: Converting Node Type Relu
# 365/460: Converting Node Type BatchNormalization
# 366/460: Converting Node Type Conv
# 367/460: Converting Node Type BatchNormalization
# 368/460: Converting Node Type Relu
# 369/460: Converting Node Type Reshape
# 370/460: Converting Node Type Transpose
# 371/460: Converting Node Type Reshape
# 372/460: Converting Node Type Pad
# 373/460: Converting Node Type Pad
# 374/460: Converting Node Type AveragePool
# 375/460: Converting Node Type BatchNormalization
# 376/460: Converting Node Type Concat
# 377/460: Converting Node Type Relu
# 378/460: Converting Node Type Conv
# 379/460: Converting Node Type Relu
# 380/460: Converting Node Type BatchNormalization
# 381/460: Converting Node Type Shape
# 382/460: Converting Node Type Gather
# 383/460: Converting Node Type Shape
# 384/460: Converting Node Type Gather
# 385/460: Converting Node Type Shape
# 386/460: Converting Node Type Gather
# 387/460: Converting Node Type Shape
# 388/460: Converting Node Type Gather
# 389/460: Converting Node Type Unsqueeze
# 390/460: Converting Node Type Unsqueeze
# 391/460: Converting Node Type Concat
# 392/460: Converting Node Type Reshape
# 393/460: Converting Node Type Conv
# 394/460: Converting Node Type Conv
# 395/460: Converting Node Type Conv
# 396/460: Converting Node Type Transpose
# 397/460: Converting Node Type MatMul
# 398/460: Converting Node Type Exp
# 399/460: Converting Node Type ReduceSum
# 400/460: Converting Node Type Div
# 401/460: Converting Node Type MatMul
# 402/460: Converting Node Type Mul
# 403/460: Converting Node Type Add
# 404/460: Converting Node Type Unsqueeze
# 405/460: Converting Node Type Unsqueeze
# 406/460: Converting Node Type Unsqueeze
# 407/460: Converting Node Type Unsqueeze
# 408/460: Converting Node Type Concat
# 409/460: Converting Node Type Reshape
# 410/460: Converting Node Type Conv
# 411/460: Converting Node Type BatchNormalization
# 412/460: Converting Node Type Relu
# 413/460: Converting Node Type Reshape
# 414/460: Converting Node Type Transpose
# 415/460: Converting Node Type Reshape
# 416/460: Converting Node Type Pad
# 417/460: Converting Node Type Pad
# 418/460: Converting Node Type AveragePool
# 419/460: Converting Node Type BatchNormalization
# 420/460: Converting Node Type Concat
# 421/460: Converting Node Type Relu
# 422/460: Converting Node Type Conv
# 423/460: Converting Node Type Relu
# 424/460: Converting Node Type BatchNormalization
# 425/460: Converting Node Type Conv
# 426/460: Converting Node Type BatchNormalization
# 427/460: Converting Node Type Relu
# 428/460: Converting Node Type Reshape
# 429/460: Converting Node Type Transpose
# 430/460: Converting Node Type Reshape
# 431/460: Converting Node Type Pad
# 432/460: Converting Node Type Pad
# 433/460: Converting Node Type AveragePool
# 434/460: Converting Node Type BatchNormalization
# 435/460: Converting Node Type Concat
# 436/460: Converting Node Type Relu
# 437/460: Converting Node Type Conv
# 438/460: Converting Node Type Relu
# 439/460: Converting Node Type BatchNormalization
# 440/460: Converting Node Type ReduceL2
# 441/460: Converting Node Type Div
# 442/460: Converting Node Type Mul
# 443/460: Converting Node Type Conv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-03ac33137021> in <module>
#       2
#       3 # Load the ONNX model as a CoreML model
# ----> 4 mlmodel = convert(model='../models/colorizer.onnx', minimum_ios_deployment_target='13', add_custom_layers=True)
#       5 # Step 2 - ONNX to CoreML model
#       6 # rename inputs/outputs
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/converter.py in convert(model, mode, image_input_names, preprocessing_args, image_output_names, deprocessing_args, class_labels, predicted_feature_name, add_custom_layers, custom_conversion_functions, onnx_coreml_input_shape_map, minimum_ios_deployment_target)
#     624         print("%d/%d: Converting Node Type %s" %(i+1, len(graph.nodes), node.op_type))
#     625         if disable_coreml_rank5_mapping:
# --> 626             _convert_node_nd(builder, node, graph, err)
#     627         else:
#     628             _add_const_inputs_if_required(builder, node, graph, err)
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/_operators_nd.py in _convert_node_nd(builder, node, graph, err)
#    2385 def _convert_node_nd(builder, node, graph, err):  # type: (NeuralNetworkBuilder, Node, Graph, ErrorHandling) -> None
#    2386     converter_fn = _get_node_converter_fn(builder, node, err)
# -> 2387     return converter_fn(builder, node, graph, err)
#    2388
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/_operators_nd.py in _convert_conv(builder, node, graph, err)
#     487         # Expected CoreML Format: H x W x KC x OC
#     488         W_name = node.inputs[1]
# --> 489         W_shape = graph.shape_dict[W_name]
#     490         W_rank  = len(W_shape)
#     491
#
# KeyError: '1178'
