# %%
from onnx_coreml import convert

# Load the ONNX model as a CoreML model
mlmodel = convert(model='colorizer.onnx', minimum_ios_deployment_target='13', add_custom_layers=True)
# Step 2 - ONNX to CoreML model
# rename inputs/outputs
#import coremltools
#spec = mlmodel.get_spec()
#coremltools.utils.rename_feature(spec, current_name='input.1', new_name='input_tensor')
#coremltools.utils.rename_feature(spec, current_name='12', new_name='network_output')
#mlmodel = coremltools.models.MLModel(spec)

# Save converted CoreML model
#mlmodel.save('small_model.mlmodel')
# Save the CoreML model
#model.save('colorizer.mlmodel')
mlmodel
# Out:
# 1/252: Converting Node Type Conv
# 2/252: Converting Node Type BatchNormalization
# 3/252: Converting Node Type Relu
# 4/252: Converting Node Type MaxPool
# 5/252: Converting Node Type Conv
# 6/252: Converting Node Type BatchNormalization
# 7/252: Converting Node Type Relu
# 8/252: Converting Node Type Conv
# 9/252: Converting Node Type BatchNormalization
# 10/252: Converting Node Type Add
# 11/252: Converting Node Type Relu
# 12/252: Converting Node Type Conv
# 13/252: Converting Node Type BatchNormalization
# 14/252: Converting Node Type Relu
# 15/252: Converting Node Type Conv
# 16/252: Converting Node Type BatchNormalization
# 17/252: Converting Node Type Add
# 18/252: Converting Node Type Relu
# 19/252: Converting Node Type Conv
# 20/252: Converting Node Type BatchNormalization
# 21/252: Converting Node Type Relu
# 22/252: Converting Node Type Conv
# 23/252: Converting Node Type BatchNormalization
# 24/252: Converting Node Type Add
# 25/252: Converting Node Type Relu
# 26/252: Converting Node Type Conv
# 27/252: Converting Node Type BatchNormalization
# 28/252: Converting Node Type Relu
# 29/252: Converting Node Type Conv
# 30/252: Converting Node Type BatchNormalization
# 31/252: Converting Node Type Conv
# 32/252: Converting Node Type BatchNormalization
# 33/252: Converting Node Type Add
# 34/252: Converting Node Type Relu
# 35/252: Converting Node Type Conv
# 36/252: Converting Node Type BatchNormalization
# 37/252: Converting Node Type Relu
# 38/252: Converting Node Type Conv
# 39/252: Converting Node Type BatchNormalization
# 40/252: Converting Node Type Add
# 41/252: Converting Node Type Relu
# 42/252: Converting Node Type Conv
# 43/252: Converting Node Type BatchNormalization
# 44/252: Converting Node Type Relu
# 45/252: Converting Node Type Conv
# 46/252: Converting Node Type BatchNormalization
# 47/252: Converting Node Type Add
# 48/252: Converting Node Type Relu
# 49/252: Converting Node Type Conv
# 50/252: Converting Node Type BatchNormalization
# 51/252: Converting Node Type Relu
# 52/252: Converting Node Type Conv
# 53/252: Converting Node Type BatchNormalization
# 54/252: Converting Node Type Add
# 55/252: Converting Node Type Relu
# 56/252: Converting Node Type Conv
# 57/252: Converting Node Type BatchNormalization
# 58/252: Converting Node Type Relu
# 59/252: Converting Node Type Conv
# 60/252: Converting Node Type BatchNormalization
# 61/252: Converting Node Type Conv
# 62/252: Converting Node Type BatchNormalization
# 63/252: Converting Node Type Add
# 64/252: Converting Node Type Relu
# 65/252: Converting Node Type Conv
# 66/252: Converting Node Type BatchNormalization
# 67/252: Converting Node Type Relu
# 68/252: Converting Node Type Conv
# 69/252: Converting Node Type BatchNormalization
# 70/252: Converting Node Type Add
# 71/252: Converting Node Type Relu
# 72/252: Converting Node Type Conv
# 73/252: Converting Node Type BatchNormalization
# 74/252: Converting Node Type Relu
# 75/252: Converting Node Type Conv
# 76/252: Converting Node Type BatchNormalization
# 77/252: Converting Node Type Add
# 78/252: Converting Node Type Relu
# 79/252: Converting Node Type Conv
# 80/252: Converting Node Type BatchNormalization
# 81/252: Converting Node Type Relu
# 82/252: Converting Node Type Conv
# 83/252: Converting Node Type BatchNormalization
# 84/252: Converting Node Type Add
# 85/252: Converting Node Type Relu
# 86/252: Converting Node Type Conv
# 87/252: Converting Node Type BatchNormalization
# 88/252: Converting Node Type Relu
# 89/252: Converting Node Type Conv
# 90/252: Converting Node Type BatchNormalization
# 91/252: Converting Node Type Add
# 92/252: Converting Node Type Relu
# 93/252: Converting Node Type Conv
# 94/252: Converting Node Type BatchNormalization
# 95/252: Converting Node Type Relu
# 96/252: Converting Node Type Conv
# 97/252: Converting Node Type BatchNormalization
# 98/252: Converting Node Type Add
# 99/252: Converting Node Type Relu
# 100/252: Converting Node Type Conv
# 101/252: Converting Node Type BatchNormalization
# 102/252: Converting Node Type Relu
# 103/252: Converting Node Type Conv
# 104/252: Converting Node Type BatchNormalization
# 105/252: Converting Node Type Conv
# 106/252: Converting Node Type BatchNormalization
# 107/252: Converting Node Type Add
# 108/252: Converting Node Type Relu
# 109/252: Converting Node Type Conv
# 110/252: Converting Node Type BatchNormalization
# 111/252: Converting Node Type Relu
# 112/252: Converting Node Type Conv
# 113/252: Converting Node Type BatchNormalization
# 114/252: Converting Node Type Add
# 115/252: Converting Node Type Relu
# 116/252: Converting Node Type Conv
# 117/252: Converting Node Type BatchNormalization
# 118/252: Converting Node Type Relu
# 119/252: Converting Node Type Conv
# 120/252: Converting Node Type BatchNormalization
# 121/252: Converting Node Type Add
# 122/252: Converting Node Type Relu
# 123/252: Converting Node Type BatchNormalization
# 124/252: Converting Node Type Relu
# 125/252: Converting Node Type Conv
# 126/252: Converting Node Type Relu
# 127/252: Converting Node Type BatchNormalization
# 128/252: Converting Node Type Conv
# 129/252: Converting Node Type Relu
# 130/252: Converting Node Type BatchNormalization
# 131/252: Converting Node Type Conv
# 132/252: Converting Node Type BatchNormalization
# 133/252: Converting Node Type Relu
# 134/252: Converting Node Type Reshape
# 135/252: Converting Node Type Transpose
# 136/252: Converting Node Type Reshape
# 137/252: Converting Node Type Pad
# 138/252: Converting Node Type Pad
# 139/252: Converting Node Type AveragePool
# 140/252: Converting Node Type BatchNormalization
# 141/252: Converting Node Type Concat
# 142/252: Converting Node Type Relu
# 143/252: Converting Node Type Conv
# 144/252: Converting Node Type Relu
# 145/252: Converting Node Type BatchNormalization
# 146/252: Converting Node Type Conv
# 147/252: Converting Node Type Relu
# 148/252: Converting Node Type BatchNormalization
# 149/252: Converting Node Type Conv
# 150/252: Converting Node Type BatchNormalization
# 151/252: Converting Node Type Relu
# 152/252: Converting Node Type Reshape
# 153/252: Converting Node Type Transpose
# 154/252: Converting Node Type Reshape
# 155/252: Converting Node Type Pad
# 156/252: Converting Node Type Pad
# 157/252: Converting Node Type AveragePool
# 158/252: Converting Node Type BatchNormalization
# 159/252: Converting Node Type Concat
# 160/252: Converting Node Type Relu
# 161/252: Converting Node Type Conv
# 162/252: Converting Node Type Relu
# 163/252: Converting Node Type BatchNormalization
# 164/252: Converting Node Type Conv
# 165/252: Converting Node Type Relu
# 166/252: Converting Node Type BatchNormalization
# 167/252: Converting Node Type Shape
# 168/252: Converting Node Type Gather
# 169/252: Converting Node Type Shape
# 170/252: Converting Node Type Gather
# 171/252: Converting Node Type Shape
# 172/252: Converting Node Type Gather
# 173/252: Converting Node Type Shape
# 174/252: Converting Node Type Gather
# 175/252: Converting Node Type Unsqueeze
# 176/252: Converting Node Type Unsqueeze
# 177/252: Converting Node Type Concat
# 178/252: Converting Node Type Reshape
# 179/252: Converting Node Type Conv
# 180/252: Converting Node Type Conv
# 181/252: Converting Node Type Conv
# 182/252: Converting Node Type Transpose
# 183/252: Converting Node Type MatMul
# 184/252: Converting Node Type Exp
# 185/252: Converting Node Type ReduceSum
# 186/252: Converting Node Type Div
# 187/252: Converting Node Type MatMul
# 188/252: Converting Node Type Mul
# 189/252: Converting Node Type Add
# 190/252: Converting Node Type Unsqueeze
# 191/252: Converting Node Type Unsqueeze
# 192/252: Converting Node Type Unsqueeze
# 193/252: Converting Node Type Unsqueeze
# 194/252: Converting Node Type Concat
# 195/252: Converting Node Type Reshape
# 196/252: Converting Node Type Conv
# 197/252: Converting Node Type BatchNormalization
# 198/252: Converting Node Type Relu
# 199/252: Converting Node Type Reshape
# 200/252: Converting Node Type Transpose
# 201/252: Converting Node Type Reshape
# 202/252: Converting Node Type Pad
# 203/252: Converting Node Type Pad
# 204/252: Converting Node Type AveragePool
# 205/252: Converting Node Type BatchNormalization
# 206/252: Converting Node Type Concat
# 207/252: Converting Node Type Relu
# 208/252: Converting Node Type Conv
# 209/252: Converting Node Type Relu
# 210/252: Converting Node Type BatchNormalization
# 211/252: Converting Node Type Conv
# 212/252: Converting Node Type Relu
# 213/252: Converting Node Type BatchNormalization
# 214/252: Converting Node Type Conv
# 215/252: Converting Node Type BatchNormalization
# 216/252: Converting Node Type Relu
# 217/252: Converting Node Type Reshape
# 218/252: Converting Node Type Transpose
# 219/252: Converting Node Type Reshape
# 220/252: Converting Node Type Pad
# 221/252: Converting Node Type Pad
# 222/252: Converting Node Type AveragePool
# 223/252: Converting Node Type BatchNormalization
# 224/252: Converting Node Type Concat
# 225/252: Converting Node Type Relu
# 226/252: Converting Node Type Conv
# 227/252: Converting Node Type Relu
# 228/252: Converting Node Type BatchNormalization
# 229/252: Converting Node Type Conv
# 230/252: Converting Node Type Relu
# 231/252: Converting Node Type BatchNormalization
# 232/252: Converting Node Type ReduceL2
# 233/252: Converting Node Type Div
# 234/252: Converting Node Type Mul
# 235/252: Converting Node Type Conv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-6bbcfdaefe6d> in <module>
#       2
#       3 # Load the ONNX model as a CoreML model
# ----> 4 mlmodel = convert(model='colorizer.onnx', minimum_ios_deployment_target='13', add_custom_layers=True)
#       5 # Step 2 - ONNX to CoreML model
#       6 # rename inputs/outputs
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/converter.py in convert(model, mode, image_input_names, preprocessing_args, image_output_names, deprocessing_args, class_labels, predicted_feature_name, add_custom_layers, custom_conversion_functions, onnx_coreml_input_shape_map, minimum_ios_deployment_target)
#     624         print("%d/%d: Converting Node Type %s" %(i+1, len(graph.nodes), node.op_type))
#     625         if disable_coreml_rank5_mapping:
# --> 626             _convert_node_nd(builder, node, graph, err)
#     627         else:
#     628             _add_const_inputs_if_required(builder, node, graph, err)
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/_operators_nd.py in _convert_node_nd(builder, node, graph, err)
#    2385 def _convert_node_nd(builder, node, graph, err):  # type: (NeuralNetworkBuilder, Node, Graph, ErrorHandling) -> None
#    2386     converter_fn = _get_node_converter_fn(builder, node, err)
# -> 2387     return converter_fn(builder, node, graph, err)
#    2388
#
# /opt/anaconda3/envs/deoldify/lib/python3.7/site-packages/onnx_coreml/_operators_nd.py in _convert_conv(builder, node, graph, err)
#     487         # Expected CoreML Format: H x W x KC x OC
#     488         W_name = node.inputs[1]
# --> 489         W_shape = graph.shape_dict[W_name]
#     490         W_rank  = len(W_shape)
#     491
#
# KeyError: '586'
